# %%
# 필요한 library 불러오기

import pandas as pd
import numpy as np
from sklearn.preprocessing import RobustScaler, MinMaxScaler, StandardScaler
from sklearn.linear_model import Ridge, Lasso, ElasticNet
from sklearn.model_selection import cross_val_score
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc
rc('font', family='AppleGothic')
plt.rcParams['axes.unicode_minus'] = False
import warnings
from sklearn.exceptions import ConvergenceWarning
warnings.simplefilter('ignore', ConvergenceWarning)
warnings.simplefilter(action='ignore', category=pd.errors.SettingWithCopyWarning)

# %%
train = pd.read_csv('train.csv')

# %%
test = pd.read_csv('test.csv')

# %%
sample_submission = pd.read_csv('sample_submission.csv')

# %%
age_gender_info = pd.read_csv('age_gender_info.csv')

# %%
train.shape
# Out:
# (2952, 15)

# %% [markdown]
# > 데이터의 수 자체가 적음, 전처리가 중요

# %%
train.isna().sum()
# Out:
# 단지코드                              0
# 총세대수                              0
# 임대건물구분                            0
# 지역                                0
# 공급유형                              0
# 전용면적                              0
# 전용면적별세대수                          0
# 공가수                               0
# 자격유형                              0
# 임대보증금                           569
# 임대료                             569
# 도보 10분거리 내 지하철역 수(환승노선 수 반영)    211
# 도보 10분거리 내 버스정류장 수                4
# 단지내주차면수                           0
# 등록차량수                             0
# dtype: int64

# %% [markdown]
# > 총 4개의 column에서 결측치 발생

# %%
test.isna().sum()
# Out:
# 단지코드                              0
# 총세대수                              0
# 임대건물구분                            0
# 지역                                0
# 공급유형                              0
# 전용면적                              0
# 전용면적별세대수                          0
# 공가수                               0
# 자격유형                              2
# 임대보증금                           180
# 임대료                             180
# 도보 10분거리 내 지하철역 수(환승노선 수 반영)     42
# 도보 10분거리 내 버스정류장 수                0
# 단지내주차면수                           0
# dtype: int64

# %% [markdown]
# > 총 4개의 column에서 결측치발생
#
# > train에서는 결측치가 발생하지않은 column : `자격유형`

# %%
train_nunique = train.nunique()
train_nunique
# Out:
# 단지코드                            423
# 총세대수                            351
# 임대건물구분                            2
# 지역                               16
# 공급유형                             10
# 전용면적                            679
# 전용면적별세대수                        403
# 공가수                              48
# 자격유형                             15
# 임대보증금                           957
# 임대료                             995
# 도보 10분거리 내 지하철역 수(환승노선 수 반영)      4
# 도보 10분거리 내 버스정류장 수               17
# 단지내주차면수                         355
# 등록차량수                           354
# dtype: int64

# %%
#데이터 타입과 unique한 값의 갯수 보기
train_type_nunique = pd.DataFrame({
    'Data Type': train.dtypes,
    'Number of Unique Values': train.nunique()
})

train_type_nunique
# Out:
#                              Data Type  Number of Unique Values
# 단지코드                            object                      423
# 총세대수                             int64                      351
# 임대건물구분                          object                        2
# 지역                              object                       16
# 공급유형                            object                       10
# 전용면적                           float64                      679
# 전용면적별세대수                         int64                      403
# 공가수                            float64                       48
# 자격유형                            object                       15
# 임대보증금                           object                      957
# 임대료                             object                      995
# 도보 10분거리 내 지하철역 수(환승노선 수 반영)   float64                        4
# 도보 10분거리 내 버스정류장 수             float64                       17
# 단지내주차면수                        float64                      355
# 등록차량수                          float64                      354

# %% [markdown]
# > object이면서 nunique가 많은 값 : `공급유형`, `자격유형`, `지역`

# %%
# 지역 data 합치기

train.loc[train.지역.isin(['경기도','서울특별시']), '지역'] = '수도권(서울/경기)'
train.loc[train.지역.isin(['경상남도','울산광역시','부산광역시','대구광역시','경상북도']), '지역'] = '경상도'
train.loc[train.지역.isin(['전라남도','광주광역시','전라북도']), '지역'] = '전라도'
train.loc[train.지역.isin(['충청남도','충청북도','대전광역시','세종특별자치시']), '지역'] = '충청도'

test.loc[test.지역.isin(['경기도','서울특별시']), '지역'] = '수도권(서울/경기)'
test.loc[test.지역.isin(['경상남도','울산광역시','부산광역시','대구광역시','경상북도']), '지역'] = '경상도'
test.loc[test.지역.isin(['전라남도','광주광역시','전라북도']), '지역'] = '전라도'
test.loc[test.지역.isin(['충청남도','충청북도','대전광역시','세종특별자치시']), '지역'] = '충청도'

# %%
train['공급유형'].unique()
# Out:
# array(['국민임대', '공공임대(50년)', '영구임대', '임대상가', '공공임대(10년)', '공공임대(분납)',
#        '장기전세', '공공분양', '행복주택', '공공임대(5년)'], dtype=object)

# %%
# train, test column rename : column명이 긴 것을 간결화
train.rename(columns={'도보 10분거리 내 지하철역 수(환승노선 수 반영)': '지하철수',
                      '도보 10분거리 내 버스정류장 수': '버스수'}, inplace=True)
test.rename(columns={'도보 10분거리 내 지하철역 수(환승노선 수 반영)': '지하철수',
                     '도보 10분거리 내 버스정류장 수': '버스수'}, inplace=True)


# 결측치 통일 : '임대료','임대보증금' 컬럼에서 '-' 값을 NaN으로 변경

for col in ['임대료', '임대보증금']:
    train[col] = train[col].replace('-', np.nan).astype(float)
    test[col] = test[col].replace('-', np.nan).astype(float)

# 해당 컬럼을 float64 타입으로 변환
train['임대료'] = train['임대료'].astype(float)
train['임대보증금'] = train['임대보증금'].astype(float)

# 해당 컬럼을 float64 타입으로 변환
test['임대료'] = test['임대료'].astype(float)
test['임대보증금'] = test['임대보증금'].astype(float)

# train - 버스수는 10으로, 지하철수는 0으로 결측치를 채움
train[train['지하철수'].isna()]['지역'].unique() # 충남, 대전, 경남으로 이 중에서 대전에만 지하철 운행 - 충남, 경남 0으로 채우기로 결정

train['버스수'].fillna(0, inplace=True)
train['지하철수'].fillna(0, inplace=True)

# test - 지하철수 0으로 결측치를 채움
test[test['지하철수'].isna()]['지역'].unique() # 충남, 대전으로 이 중에서 대전에만 지하철 운행 - 충남 0으로 채우기로 결정

test['지하철수'].fillna(0, inplace=True)

#자격유형 결측치 확인
test[test['자격유형'].isna()]

#C2411 자격유형 → 'A'
test[test['단지코드']=='C2411'] #C2411 자격유형이 모두 A로, 단순 결측치인 것으로 판단
test[test['단지코드']=='C2411']['자격유형'].fillna('A')

#C2253 자격유형 → 'C'
test[test['단지코드']=='C2253'] #자격유형 C, D를 구분하는 컬럼이 '임대건물구분'이라고 판단, 결측치는 임대건물구분이 아파트이기 때문에 자격유형 C로 채워넣음
test[test['단지코드']=='C2253']['자격유형'].fillna('C')

train.head()
# Out:
#     단지코드  총세대수 임대건물구분   지역  공급유형   전용면적  전용면적별세대수   공가수 자격유형       임대보증금  \
# 0  C2483   900    아파트  경상도  국민임대  39.72       134  38.0    A  15667000.0
# 1  C2483   900    아파트  경상도  국민임대  39.72        15  38.0    A  15667000.0
# 2  C2483   900    아파트  경상도  국민임대  51.93       385  38.0    A  27304000.0
# 3  C2483   900    아파트  경상도  국민임대  51.93        15  38.0    A  27304000.0
# 4  C2483   900    아파트  경상도  국민임대  51.93        41  38.0    A  27304000.0
#
#         임대료  지하철수  버스수  단지내주차면수   등록차량수
# 0  103680.0   0.0  3.0   1425.0  1015.0
# 1  103680.0   0.0  3.0   1425.0  1015.0
# 2  184330.0   0.0  3.0   1425.0  1015.0
# 3  184330.0   0.0  3.0   1425.0  1015.0
# 4  184330.0   0.0  3.0   1425.0  1015.0

# %%
train[train['지하철수'].isna()]['지역'].unique()
# Out:
# array([], dtype=object)

# %%
# 임대료 혹은 임대보증금이 NaN값인 행 필터링
missing_data = train[train['임대료'].isna() | train['임대보증금'].isna()]

# 모든 열에 대해 통계요약값과 누락 데이터 몇 행정도 표시
summary = missing_data.describe(include='all')
summary
# Out:
#          단지코드         총세대수 임대건물구분   지역  공급유형        전용면적    전용면적별세대수  \
# count     590   590.000000    590  590   590  590.000000  590.000000
# unique     39          NaN      2    5     5         NaN         NaN
# top     C1439          NaN     상가  경상도  임대상가         NaN         NaN
# freq       45          NaN    562  325   562         NaN         NaN
# mean      NaN  1236.922034    NaN  NaN   NaN   45.542356    7.984746
# std       NaN   652.934635    NaN  NaN   NaN   66.314353   45.403471
# min       NaN   370.000000    NaN  NaN   NaN   12.620000    1.000000
# 25%       NaN   657.000000    NaN  NaN   NaN   26.250000    1.000000
# 50%       NaN  1005.000000    NaN  NaN   NaN   31.840000    1.000000
# 75%       NaN  1755.000000    NaN  NaN   NaN   37.950000    1.000000
# max       NaN  2428.000000    NaN  NaN   NaN  583.400000  590.000000
#
#                공가수 자격유형         임대보증금  임대료        지하철수         버스수  \
# count   590.000000  590  9.000000e+00  0.0  590.000000  590.000000
# unique         NaN    4           NaN  NaN         NaN         NaN
# top            NaN    D           NaN  NaN         NaN         NaN
# freq           NaN  569           NaN  NaN         NaN         NaN
# mean      7.886441  NaN  1.842430e+08  NaN    0.288136    3.679661
# std      10.514231  NaN  3.962353e+07  NaN    0.453279    2.308343
# min       0.000000  NaN  8.744400e+07  NaN    0.000000    1.000000
# 25%       1.000000  NaN  1.748880e+08  NaN    0.000000    2.000000
# 50%       2.000000  NaN  1.945620e+08  NaN    0.000000    3.000000
# 75%       9.000000  NaN  2.138630e+08  NaN    1.000000    4.000000
# max      43.000000  NaN  2.164230e+08  NaN    1.000000   12.000000
#
#             단지내주차면수        등록차량수
# count    590.000000   590.000000
# unique          NaN          NaN
# top             NaN          NaN
# freq            NaN          NaN
# mean     313.910169   213.735593
# std      293.986239   308.756185
# min       65.000000    31.000000
# 25%      153.000000    94.000000
# 50%      217.000000   127.000000
# 75%      351.000000   189.000000
# max     1670.000000  2315.000000

# %%
print("임대건물구분이 상가인 것의 임대료",train[train['임대건물구분'] == '상가']['임대료'].unique())
print("임대건물구분이 상가인 것의 임대보증금",train[train['임대건물구분'] == '상가']['임대보증금'].unique())
print("공급유형이 임대상가인 것의 임대료",train[train['공급유형']=='임대상가']['임대료'].unique())
print("공급유형이 임대상가인 것의 임대보증금",train[train['공급유형']=='임대상가']['임대보증금'].unique())
print("자격유형이 D인 것의 임대료",train[train['자격유형'] == 'D']['임대료'].unique())
print("자격유형이 D인 것의 임대보증금",train[train['자격유형'] == 'D']['임대보증금'].unique())
# Out:
# 임대건물구분이 상가인 것의 임대료 [nan]
# 임대건물구분이 상가인 것의 임대보증금 [nan]
# 공급유형이 임대상가인 것의 임대료 [nan]
# 공급유형이 임대상가인 것의 임대보증금 [nan]
# 자격유형이 D인 것의 임대료 [nan]
# 자격유형이 D인 것의 임대보증금 [nan]

# %% [markdown]
# > 해당하는 조건을 해봤으나 모두 nan값이라 유의미한 결과를 도출할 수 없음

# %% [markdown]
# > 상가가 아닌 것의 데이터를 살펴보았습니다.

# %%
train[(train['임대료'].isna()) & (train['임대건물구분'] != '상가')]
# Out:
#        단지코드  총세대수 임대건물구분          지역  공급유형   전용면적  전용면적별세대수   공가수 자격유형  \
# 2043  C1397   370    아파트  수도권(서울/경기)  장기전세  23.32        51   9.0    A
# 2044  C1397   370    아파트  수도권(서울/경기)  장기전세  46.79         4   9.0    A
# 2045  C1397   370    아파트  수도권(서울/경기)  장기전세  46.91        69   9.0    A
# 2046  C1397   370    아파트  수도권(서울/경기)  장기전세  51.96        24   9.0    A
# 2047  C1397   370    아파트  수도권(서울/경기)  장기전세  51.99        80   9.0    A
# 2048  C1397   370    아파트  수도권(서울/경기)  장기전세  59.93       142   9.0    A
# 2100  C1039   790    아파트  수도권(서울/경기)  장기전세  51.32       126  13.0    A
# 2101  C1039   790    아파트  수도권(서울/경기)  장기전세  59.88        49  13.0    A
# 2102  C1039   790    아파트  수도권(서울/경기)  장기전세  59.94        75  13.0    A
# 2331  C1350  1401    아파트         충청도  공공분양  74.94       317   2.0    D
# 2332  C1350  1401    아파트         충청도  공공분양  74.94       137   2.0    D
# 2333  C1350  1401    아파트         충청도  공공분양  74.94        22   2.0    D
# 2334  C1350  1401    아파트         충청도  공공분양  84.94       164   2.0    D
# 2335  C1350  1401    아파트         충청도  공공분양  84.94        19   2.0    D
# 2336  C1350  1401    아파트         충청도  공공분양  84.96        26   2.0    D
# 2337  C1350  1401    아파트         충청도  공공분양  84.97        26   2.0    D
# 2547  C1326  1934    아파트         경상도  국민임대  24.72       472  43.0    H
# 2548  C1326  1934    아파트         경상도  국민임대  24.79       104  43.0    H
# 2549  C1326  1934    아파트         경상도  국민임대  26.83       590  43.0    H
# 2550  C1326  1934    아파트         경상도  국민임대  37.70       464  43.0    H
# 2551  C1326  1934    아파트         경상도  국민임대  46.94       304  43.0    H
# 2680  C1786   480    아파트         강원도  행복주택  16.91       156  25.0    K
# 2681  C1786   480    아파트         강원도  행복주택  26.90       136  25.0    K
# 2682  C1786   480    아파트         강원도  행복주택  26.90        72  25.0    K
# 2683  C1786   480    아파트         강원도  행복주택  26.90        24  25.0    K
# 2906  C2186   924    아파트         경상도  국민임대  29.17       238   0.0    H
# 2907  C2186   924    아파트         경상도  국민임대  29.34        38   0.0    H
# 2908  C2186   924    아파트         경상도  국민임대  37.43       220   0.0    H
#
#             임대보증금  임대료  지하철수  버스수  단지내주차면수   등록차량수
# 2043   87444000.0  NaN   0.0  3.0   1590.0  1595.0
# 2044  174888000.0  NaN   0.0  3.0   1590.0  1595.0
# 2045  174888000.0  NaN   0.0  3.0   1590.0  1595.0
# 2046  194562000.0  NaN   0.0  3.0   1590.0  1595.0
# 2047  194562000.0  NaN   0.0  3.0   1590.0  1595.0
# 2048  216423000.0  NaN   0.0  3.0   1590.0  1595.0
# 2100  187694000.0  NaN   0.0  3.0    673.0   645.0
# 2101  213863000.0  NaN   0.0  3.0    673.0   645.0
# 2102  213863000.0  NaN   0.0  3.0    673.0   645.0
# 2331          NaN  NaN   0.0  6.0   1636.0  2315.0
# 2332          NaN  NaN   0.0  6.0   1636.0  2315.0
# 2333          NaN  NaN   0.0  6.0   1636.0  2315.0
# 2334          NaN  NaN   0.0  6.0   1636.0  2315.0
# 2335          NaN  NaN   0.0  6.0   1636.0  2315.0
# 2336          NaN  NaN   0.0  6.0   1636.0  2315.0
# 2337          NaN  NaN   0.0  6.0   1636.0  2315.0
# 2547          NaN  NaN   0.0  4.0   1670.0  1153.0
# 2548          NaN  NaN   0.0  4.0   1670.0  1153.0
# 2549          NaN  NaN   0.0  4.0   1670.0  1153.0
# 2550          NaN  NaN   0.0  4.0   1670.0  1153.0
# 2551          NaN  NaN   0.0  4.0   1670.0  1153.0
# 2680          NaN  NaN   0.0  3.0    338.0   345.0
# 2681          NaN  NaN   0.0  3.0    338.0   345.0
# 2682          NaN  NaN   0.0  3.0    338.0   345.0
# 2683          NaN  NaN   0.0  3.0    338.0   345.0
# 2906          NaN  NaN   0.0  8.0    664.0   744.0
# 2907          NaN  NaN   0.0  8.0    664.0   744.0
# 2908          NaN  NaN   0.0  8.0    664.0   744.0

# %%
test[(test['임대료'].isna()) & (test['임대건물구분'] != '상가')]
# Out:
#        단지코드  총세대수 임대건물구분   지역  공급유형   전용면적  전용면적별세대수   공가수 자격유형  임대보증금  임대료  \
# 76    C1006  1505    아파트  충청도  영구임대  26.37        10  27.0    D    NaN  NaN
# 77    C1006  1505    아파트  충청도  영구임대  26.37        10  27.0    D    NaN  NaN
# 79    C1006  1505    아파트  충청도  영구임대  52.74         6  27.0    D    NaN  NaN
# 1005  C2152   120    아파트  강원도  영구임대  24.83        66   9.0    C    NaN  NaN
# 1006  C2152   120    아파트  강원도  영구임대  33.84        54   9.0    C    NaN  NaN
# 1014  C1267   675    아파트  경상도  행복주택  16.94        50  38.0    L    NaN  NaN
# 1015  C1267   675    아파트  경상도  행복주택  26.85        66  38.0    L    NaN  NaN
# 1016  C1267   675    아파트  경상도  행복주택  26.85         8  38.0    L    NaN  NaN
# 1017  C1267   675    아파트  경상도  행복주택  36.77       126  38.0    L    NaN  NaN
#
#       지하철수  버스수  단지내주차면수
# 76     2.0  5.0    428.0
# 77     2.0  5.0    428.0
# 79     2.0  5.0    428.0
# 1005   0.0  1.0     40.0
# 1006   0.0  1.0     40.0
# 1014   0.0  1.0    467.0
# 1015   0.0  1.0    467.0
# 1016   0.0  1.0    467.0
# 1017   0.0  1.0    467.0

# %% [markdown]
# > 다른 행들은 임대보증금과 임대료가 모두 결측치이지만 장기전세는 임대료만 결측치인 것을 확인할 수 있습니다.
#
# > 장기전세주택이란 월 임대료를 지불하지 않고 전세계약 방식으로 공급되는 공공임대주택을 말합니다. [출처](https://www.mylawstory.com/5606/)
#
# >그러므로 장기전세의 임대료는 0으로 바꿔주는 것이 맞습니다

# %%
#### 장기전세는 월 임대료를 지불하지않으므로 임대료 = 0 적용
train.loc[train['공급유형'] == '장기전세', '임대료'] = 0
test.loc[test['공급유형'] == '장기전세', '임대료'] = 0

# %% [markdown]
# > 단지내 주차면수과 임대료, 임대보증금이 높은 상관관계를 가지므로
#
# > 공급유형이 상가가 아닌것들 중에 임대료와 임대보증금이 결측치인경우 지역별로 나눈 후 단지내 주차면수에 따른 회귀모델을 통해 임대료와 임대보증금의 결측치를 채워줍니다.

# %%
#train data 상가아닌 것 임대료, 임대보증금 회귀예측

from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# 공급유형이 상가가 아닌 행만 남도록 필터링
train_non_store = train[train['공급유형'] != '상가']

# train_non_store 데이터의 지역명 확인
regions = train_non_store['지역'].unique()

# 예측값 저장을 위해 빈 리스트 생성
predicted_rent = [] #임대료 예측값 리스트
predicted_deposit = [] #임대보증금 예측값 리스트

# 지역을 기준으로 반복
for region in regions:
    region_data = train_non_store[train_non_store['지역'] == region].copy()

    # 임대료에 대한 회귀 모델 학습
    # 임대료 열에 결측값이 없는 데이터를 선택하고, 단지내주차면수을 X, 임대료를 y로 사용
    X = region_data[~region_data['임대료'].isna()][['단지내주차면수']]
    y = region_data[~region_data['임대료'].isna()]['임대료']
    if len(X) > 0:
        model_rent = LinearRegression()
        model_rent.fit(X, y)
        # 결측치 예측
        # 임대료 열에 결측치 있는 데이터 선택하여 전용면적을 X로 사용하여 임대료 예측
        X_missing_rent = region_data[region_data['임대료'].isna()][['단지내주차면수']]
        if len(X_missing_rent) > 0:
            pred_rent = model_rent.predict(X_missing_rent)
            predicted_rent.extend(pred_rent)

    # 임대보증금에 대한 회귀 모델 학습
    # 임대보증금 열에 결측값이 없는 데이터를 선택하고, 전용면적을 X, 임대보증금를 y로 사용
    X = region_data[~region_data['임대보증금'].isna()][['단지내주차면수']]
    y = region_data[~region_data['임대보증금'].isna()]['임대보증금']
    if len(X) > 0:
        model_deposit = LinearRegression()
        model_deposit.fit(X, y)
        # 결측치 예측
        X_missing_deposit = region_data[region_data['임대보증금'].isna()][['단지내주차면수']]
        # 데이터가 존재하면 모델을 사용해 임대료를 예측하고 리스트에 추가하도록 함
        if len(X_missing_deposit) > 0:
            pred_deposit = model_deposit.predict(X_missing_deposit)
            predicted_deposit.extend(pred_deposit)

# train_non_store의 임대료와 임대보증금이 결측치인 것들을 채워넣음
missing_rent_indices = train_non_store[train_non_store['임대료'].isna()].index
for idx, value in zip(missing_rent_indices, predicted_rent):
    train.at[idx, '임대료'] = value

missing_deposit_indices = train_non_store[train_non_store['임대보증금'].isna()].index
for idx, value in zip(missing_deposit_indices, predicted_deposit):
    train.at[idx, '임대보증금'] = value

# 결측치 채워졌는지 확인
missing_values = train[train['공급유형'] != '상가'][['임대료', '임대보증금']].isnull().sum()

missing_values
# Out:
# 임대료      0
# 임대보증금    0
# dtype: int64

# %%
# test 데이터 공급유형이 상가가 아닌 것만 남도록 필터링
test_non_store = test[test['공급유형'] != '상가']

# 지역명 추출
regions = test_non_store['지역'].unique()

# 예측값 저장을 위해 빈 리스트 생성
predicted_rent = [] #임대료 예측값 저장 리스트
predicted_deposit = [] #임대보증금 예측값 저장 리스트

# 지역을 기준으로 반복문 돌림
for region in regions:
    region_data = test_non_store[test_non_store['지역'] == region].copy()

    # 임대료에 대한 회귀 모델 학습
    X = region_data[~region_data['임대료'].isna()][['단지내주차면수']]
    y = region_data[~region_data['임대료'].isna()]['임대료']
    if len(X) > 0:
        model_rent = LinearRegression()
        model_rent.fit(X, y)
        # 결측치 예측
        X_missing_rent = region_data[region_data['임대료'].isna()][['단지내주차면수']]
        # 데이터가 존재하면 모델을 사용해 임대료를 예측하고 리스트에 추가하도록 함
        if len(X_missing_rent) > 0:
            pred_rent = model_rent.predict(X_missing_rent)
            predicted_rent.extend(pred_rent)

    # 임대보증금에 대해서도 동일하게 회귀 모델 학습
    X = region_data[~region_data['임대보증금'].isna()][['단지내주차면수']]
    y = region_data[~region_data['임대보증금'].isna()]['임대보증금']
    if len(X) > 0:
        model_deposit = LinearRegression()
        model_deposit.fit(X, y)
        # 결측치 예측
        X_missing_deposit = region_data[region_data['임대보증금'].isna()][['단지내주차면수']]
        # 데이터가 존재하면 모델을 사용해 임대보증금을 예측하고 리스트에 추가하도록 함
        if len(X_missing_deposit) > 0:
            pred_deposit = model_deposit.predict(X_missing_deposit)
            predicted_deposit.extend(pred_deposit)

# test_non_store 결측치를 예측한 임대료와 임대보증금 값으로 채움
missing_rent_indices = test_non_store[test_non_store['임대료'].isna()].index
for idx, value in zip(missing_rent_indices, predicted_rent):
    test.at[idx, '임대료'] = value

missing_deposit_indices = test_non_store[test_non_store['임대보증금'].isna()].index
for idx, value in zip(missing_deposit_indices, predicted_deposit):
    test.at[idx, '임대보증금'] = value

# 결측치 채워졌는지 확인
missing_values = test[test['공급유형'] != '상가'][['임대료', '임대보증금']].isnull().sum()

missing_values
# Out:
# 임대료      0
# 임대보증금    0
# dtype: int64

# %% [markdown]
# > train에는 있는데 test에는 없는 값들이 존재함
# ---
# - 장기전세, 공공임대(5년), 공공분양
# - 자격유형 : B, F, O
# - 단지코드

# %%
train['공급유형'].value_counts()
# Out:
# 공급유형
# 국민임대         1758
# 임대상가          562
# 행복주택          213
# 공공임대(10년)     205
# 영구임대          152
# 공공임대(50년)      31
# 공공임대(분납)       12
# 장기전세            9
# 공공분양            7
# 공공임대(5년)        3
# Name: count, dtype: int64

# %%
test['공급유형'].value_counts()
# Out:
# 공급유형
# 국민임대         622
# 임대상가         177
# 행복주택         124
# 영구임대          45
# 공공임대(10년)     35
# 공공임대(50년)     13
# 공공임대(분납)       6
# Name: count, dtype: int64

# %% [markdown]
#  - 장기전세, 공공임대(5년), 공공분양이 train에서만 존재함
#  -- '공공'으로 시작하는 거끼리 묶고, 장기전세는 장기적으로 주택을 임대, 국민 임대 역시 장기 임대한다는 점에서 둘을 묶기로 결정

# %%
train.loc[train.공급유형.isin(['공공임대(5년)', '공공분양', '공공임대(10년)', '공공임대(분납)','공공임대(50년)']), '공급유형'] = '공공임대(5년/10년/분납/분양)'
test.loc[test.공급유형.isin(['공공임대(5년)', '공공분양', '공공임대(10년)', '공공임대(분납)','공공임대(50년)']), '공급유형'] = '공공임대(5년/10년/분납/분양)'

train.loc[train.공급유형.isin(['장기전세', '국민임대']), '공급유형'] = '국민임대/장기전세'
test.loc[test.공급유형.isin(['장기전세', '국민임대']), '공급유형'] = '국민임대/장기전세'

# %%
print(train['공급유형'].value_counts())
print('-----'*10)
print(test['공급유형'].value_counts())
#column값 차이 없는 것 확인
# Out:
# 공급유형
# 국민임대/장기전세             1767
# 임대상가                   562
# 공공임대(5년/10년/분납/분양)     258
# 행복주택                   213
# 영구임대                   152
# Name: count, dtype: int64
# --------------------------------------------------
# 공급유형
# 국민임대/장기전세             622
# 임대상가                  177
# 행복주택                  124
# 공공임대(5년/10년/분납/분양)     54
# 영구임대                   45
# Name: count, dtype: int64

# %%
train['자격유형'].value_counts()
# B- 21
# F -3
# O -1
# 데이터가 적어서 바로 앞의 자격 유형과 묶어도 무방할 것 같음
# Out:
# 자격유형
# A    1801
# D     569
# H     155
# J     114
# C      95
# I      49
# E      37
# K      33
# L      33
# N      30
# B      21
# G       9
# F       3
# M       2
# O       1
# Name: count, dtype: int64

# %%
test['자격유형'].value_counts()
# Out:
# 자격유형
# A    572
# D    180
# H     92
# J     84
# C     34
# K     16
# L     12
# E     10
# N     10
# I      7
# M      2
# G      1
# Name: count, dtype: int64

# %%
# B,F,O 각 자격유형의 바로 앞 자격유형과 통합함
train['자격유형'] = train['자격유형'].apply(lambda x: 'A-B' if x in ['A', 'B'] else x)
test['자격유형'] = test['자격유형'].apply(lambda x: 'A-B' if x in ['A', 'B'] else x)

train['자격유형'] = train['자격유형'].apply(lambda x: 'E-F' if x in ['E', 'F'] else x)
test['자격유형'] = test['자격유형'].apply(lambda x: 'E-F' if x in ['E', 'F'] else x)

train['자격유형'] = train['자격유형'].apply(lambda x: 'N-O' if x in ['N', 'O'] else x)
test['자격유형'] = test['자격유형'].apply(lambda x: 'N-O' if x in ['N', 'O'] else x)

train['자격유형'].value_counts()
# Out:
# 자격유형
# A-B    1822
# D       569
# H       155
# J       114
# C        95
# I        49
# E-F      40
# K        33
# L        33
# N-O      31
# G         9
# M         2
# Name: count, dtype: int64

# %%
train.shape, train.drop_duplicates().shape #중복존재
# Out:
# ((2952, 15), (2651, 15))

# %%
test.shape, test.drop_duplicates().shape #중복존재
# Out:
# ((1022, 14), (952, 14))

# %%
train = train.drop_duplicates()
test=test.drop_duplicates()

# %% [markdown]
# > data type이 object인 것을 모두 인코딩(원-핫 인코딩 사용)

# %%
# # '전체전용면적' 열 생성
# train['전체전용면적'] = train['전용면적'] * train['전용면적별세대수']
# test['전체전용면적'] = test['전용면적'] * test['전용면적별세대수']
# # '전용면적'과 '전용면적별세대수' 열 제거
# train = train.drop(['전용면적', '전용면적별세대수'], axis=1)
# test = test.drop(['전용면적', '전용면적별세대수'], axis=1)


# train['임대보증금_임대료'] = train['임대보증금'] * train['임대료']
# test['임대보증금_임대료'] = test['임대보증금'] * test['임대료']

# train = train.drop(['임대보증금', '임대료'], axis=1)
# test = test.drop(['임대보증금', '임대료'], axis=1)

# %%
train.columns
# Out:
# Index(['단지코드', '총세대수', '임대건물구분', '지역', '공급유형', '전용면적', '전용면적별세대수', '공가수',
#        '자격유형', '임대보증금', '임대료', '지하철수', '버스수', '단지내주차면수', '등록차량수'],
#       dtype='object')

# %%
# def process_dataframe(df, is_train=True):
#     # Exclude object data type columns
#     numeric_cols = df.select_dtypes(exclude='object').columns
#     if is_train:
#         numeric_cols = numeric_cols.drop('등록차량수')
#     mean_df = df.groupby('단지코드')[numeric_cols].mean()
#     mean_df = mean_df.add_prefix('평균')
#     df = df.merge(mean_df, on='단지코드', how='left')
#     df.drop(numeric_cols, axis=1, inplace=True)
#     return df

# # Apply function to train and test data
# train = process_dataframe(train, is_train=True)
# test = process_dataframe(test, is_train=False)

# %%
train.dtypes
# Out:
# 단지코드         object
# 총세대수          int64
# 임대건물구분       object
# 지역           object
# 공급유형         object
# 전용면적        float64
# 전용면적별세대수      int64
# 공가수         float64
# 자격유형         object
# 임대보증금       float64
# 임대료         float64
# 지하철수        float64
# 버스수         float64
# 단지내주차면수     float64
# 등록차량수       float64
# dtype: object

# %%
# train['총세대수_공가수'] = train['평균총세대수'] - train['평균공가수']
# test['총세대수_공가수'] = test['평균총세대수'] - test['평균공가수']

# train = train.drop(['평균공가수', '평균총세대수'], axis=1)
# test = test.drop(['평균공가수', '평균총세대수'], axis=1)

# %%
# '단지코드'를 제외하고 object인 열을 모두 원-핫 인코딩 진행

# 인코딩할 object 열을 식별
object_columns = train.select_dtypes(include=['object']).columns.tolist()
object_columns.remove('단지코드')  # '단지코드' 열은 제외하여 인코딩하지 않음

# train, test에 대해 원-핫 인코딩 진행
train_encoded = pd.get_dummies(train, columns=object_columns)
test_encoded = pd.get_dummies(test, columns=object_columns)

# 인코딩이 진행된 train 데이터의 열 확인
train_encoded.head()
train_encoded.columns
# Out:
# Index(['단지코드', '총세대수', '전용면적', '전용면적별세대수', '공가수', '임대보증금', '임대료', '지하철수',
#        '버스수', '단지내주차면수', '등록차량수', '임대건물구분_상가', '임대건물구분_아파트', '지역_강원도',
#        '지역_경상도', '지역_수도권(서울/경기)', '지역_전라도', '지역_제주특별자치도', '지역_충청도',
#        '공급유형_공공임대(5년/10년/분납/분양)', '공급유형_국민임대/장기전세', '공급유형_영구임대', '공급유형_임대상가',
#        '공급유형_행복주택', '자격유형_A-B', '자격유형_C', '자격유형_D', '자격유형_E-F', '자격유형_G',
#        '자격유형_H', '자격유형_I', '자격유형_J', '자격유형_K', '자격유형_L', '자격유형_M', '자격유형_N-O'],
#       dtype='object')

# %%
# '임대건물구분'이 '상가'인 경우 '임대료', '임대보증금' 값을 drop
# '임대건물구분'이 '상가'가 아닌 경우는 drop없이 그대로 진행

train_store_data = train_encoded[train_encoded['임대건물구분_상가'] == 1].drop(columns=['임대보증금','임대료'])
train_non_store_data = train_encoded[train_encoded['임대건물구분_상가'] != 1]

test_store_data = test_encoded[test_encoded['임대건물구분_상가'] == 1].drop(columns=['임대보증금','임대료'])
test_non_store_data = test_encoded[test_encoded['임대건물구분_상가'] != 1]

# %% [markdown]
# ### `임대건물구분`이 상가인 것을 학습데이터로 나누고, 정규화를 두가지 방법(minMax Scaler, Stndardization Scaler)로 진행한 후,
# ### Ridge, Lasso, ElasticNet 회귀 모델을 사용하여 MAE값이 가장 낮은것을 출력

# %%
#'임대건물구분'이 '상가'와 '상가가 아닌 것'으로 데이터를 분리
features_store = train_store_data.columns.drop(['등록차량수', '단지코드']).tolist()
features_nonstore = train_non_store_data.columns.drop(['등록차량수', '단지코드']).tolist()
target = '등록차량수'

X_store =train_store_data[features_store]
y_store=train_store_data[target]

X_non_store =train_non_store_data[features_nonstore]
y_non_store=train_non_store_data[target]

# 훈련 데이터와 검증 데이터로 분리
X_train_store, X_val_store, y_train_store, y_val_store = train_test_split(X_store, y_store, test_size=0.2, random_state=42)
X_train_non_store, X_val_non_store, y_train_non_store, y_val_non_store = train_test_split(X_non_store, y_non_store, test_size=0.2, random_state=42)

# Initialize scalers again
Robust_scaler = RobustScaler()
minmax_scaler = MinMaxScaler()
standard_scaler = StandardScaler()

# Apply Robust Scaling

X_train_store_robust = Robust_scaler.fit_transform(X_train_store)
X_val_store_robust = Robust_scaler.transform(X_val_store)

X_train_non_store_robust = Robust_scaler.fit_transform(X_train_non_store)
X_val_non_store_robust = Robust_scaler.transform(X_val_non_store)

# Apply MinMax Scaling

X_train_store_minmax = minmax_scaler.fit_transform(X_train_store)
X_val_store_minmax = minmax_scaler.transform(X_val_store)

X_train_non_store_minmax = minmax_scaler.fit_transform(X_train_non_store)
X_val_non_store_minmax = minmax_scaler.transform(X_val_non_store)

# Apply Standard Scaling
X_train_store_std = standard_scaler.fit_transform(X_train_store)
X_val_store_std = standard_scaler.transform(X_val_store)

X_train_non_store_std = standard_scaler.fit_transform(X_train_non_store)
X_val_non_store_std = standard_scaler.transform(X_val_non_store)

# %%
import numpy as np
from sklearn.linear_model import Lasso, Ridge, ElasticNet
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import mean_absolute_error
import xgboost as xgb
from sklearn.ensemble import RandomForestRegressor

Robust_scaler = RobustScaler()
minmax_scaler = MinMaxScaler()
standard_scaler = StandardScaler()

# 모델 및 파라미터 그리드 설정
models = {
    'Lasso': Lasso(),
    'Ridge': Ridge(),
    'ElasticNet': ElasticNet(),
    'XGBoost' : xgb.XGBRegressor(objective='reg:squarederror', random_state=42)
    # 'RandomForest' : RandomForestRegressor(random_state=42)
}

params = {
    'Lasso': {
        'alpha': [0.001, 0.01, 0.1, 1, 10, 100],
        'max_iter': [500, 1000,5000,10000],
        'tol': [0.00001,0.0001, 0.001]
    },
    'Ridge': {
        'alpha': [0.001, 0.01, 0.1, 1, 10, 100],
        'max_iter': [500, 1000,5000,10000],
        'tol': [0.00001,0.0001, 0.001]
    },
    'ElasticNet': {
        'alpha': [0.001, 0.01, 0.1, 1, 10, 100],
        'l1_ratio': [.1, .5, .7, .9, .95, .99, 1],
        'max_iter': [100,500, 1000],
        'tol': [0.00001,0.0001, 0.001, 0.01]
    },
    'XGBoost' : {
                 'max_depth' : np.arange(5,9,1) ,
                  "n_estimators": [500],
                  'min_child_weight' : np.arange(1, 5, 1), 
                  'gamma' : [0,1,2,3],
                  "learning_rate": [0.05, 0.075, 0.1],
                  'subsample' :np.arange(0.8, 1.0, 0.1)
    }
    # 'RandomForest' : {
    #     'n_estimators' : [100,500,1000],
    #     'max_features' :  ['sqrt'],
    #     'max_depth' : [10, 20, 30, 40, 50],
    #     'min_samples_split' :  [2],
    #     'bootstrap' :  [False]
    # }
}

# 스케일링 방법
scaling_methods = {
    'Robust Scaling': (X_train_store_robust, X_val_store_robust),
    'MinMax Scaling': (X_train_store_minmax, X_val_store_minmax),
    'Standard Scaling': (X_train_store_std, X_val_store_std)
}

# 그리드 서치 및 MAE 계산
best_mae = float('inf')
best_model = None
best_params = None
best_scaling = None

for name, model in models.items():
    for method, (X_train_store_scaled, X_val_store_scaled) in scaling_methods.items():
        grid = GridSearchCV(model, params[name], cv=5, n_jobs=-1, scoring='neg_mean_absolute_error')
        grid.fit(X_train_store_scaled, y_train_store)
        y_pred_store = grid.predict(X_val_store_scaled)
        mae = mean_absolute_error(y_val_store, y_pred_store)

        if mae < best_mae:
            best_mae_store = mae
            best_model_store = name
            best_params_store = grid.best_params_
            best_scaling_store = method

print(f"Best Model: {best_model_store}")
print(f"Best Scaling Method: {best_scaling_store}")
print(f"Best Parameters: {best_params_store}")
print(f"Best MAE: {best_mae_store}")
# Out:
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.011e+02, tolerance: 2.219e+01
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.162e+01, tolerance: 2.219e+01
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.010e+02, tolerance: 2.219e+01
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.152e+01, tolerance: 2.219e+01
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.129e+02, tolerance: 2.172e+01
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.351e+02, tolerance: 2.211e+01
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.425e+02, tolerance: 2.254e+01
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.428e+02, tolerance: 2.399e+01
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.129e+02, tolerance: 2.172e+01
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.351e+02, tolerance: 2.211e+01
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.428e+02, tolerance: 2.399e+01
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.425e+02, tolerance: 2.254e+01
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.129e+02, tolerance: 2.172e+01
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.424e+02, tolerance: 2.254e+01
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.427e+02, tolerance: 2.399e+01
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.328e+02, tolerance: 2.172e+01
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.588e+02, tolerance: 2.211e+01
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.690e+02, tolerance: 2.254e+01
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.950e+01, tolerance: 2.219e+01
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.697e+02, tolerance: 2.399e+01
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.578e+02, tolerance: 2.211e+01
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.680e+02, tolerance: 2.254e+01
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.350e+02, tolerance: 2.211e+01
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.349e+02, tolerance: 2.211e+01
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.318e+02, tolerance: 2.172e+01
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.753e+01, tolerance: 2.219e+01
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.687e+02, tolerance: 2.399e+01
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.426e+02, tolerance: 2.399e+01
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.128e+02, tolerance: 2.172e+01
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.240e+02, tolerance: 2.172e+01
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.600e+02, tolerance: 2.254e+01
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.426e+02, tolerance: 2.172e+01
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.058e+02, tolerance: 2.211e+01
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.072e+02, tolerance: 2.211e+01
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.435e+02, tolerance: 2.254e+01
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.431e+02, tolerance: 2.254e+01
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.155e+02, tolerance: 2.219e+01
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.463e+02, tolerance: 2.399e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.463e+02, tolerance: 2.399e+01
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.426e+02, tolerance: 2.172e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.058e+02, tolerance: 2.211e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.435e+02, tolerance: 2.254e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.451e+02, tolerance: 2.399e+01
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.499e+02, tolerance: 2.211e+01
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.423e+02, tolerance: 2.254e+01
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.451e+02, tolerance: 2.399e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.431e+02, tolerance: 2.254e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.504e+02, tolerance: 2.399e+01
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.400e+02, tolerance: 2.211e+01
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.606e+02, tolerance: 2.399e+01
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.500e+02, tolerance: 2.254e+01
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.259e+05, tolerance: 2.172e+01
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.370e+05, tolerance: 2.211e+01
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.189e+05, tolerance: 2.254e+01
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.443e+05, tolerance: 2.219e+01
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.279e+05, tolerance: 2.399e+01
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.259e+05, tolerance: 2.172e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.370e+05, tolerance: 2.211e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.189e+05, tolerance: 2.254e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.443e+05, tolerance: 2.219e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.279e+05, tolerance: 2.399e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.259e+05, tolerance: 2.172e+03
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.370e+05, tolerance: 2.211e+03
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.189e+05, tolerance: 2.254e+03
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.443e+05, tolerance: 2.219e+03
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.279e+05, tolerance: 2.399e+03
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.259e+05, tolerance: 2.172e+04
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.370e+05, tolerance: 2.211e+04
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.443e+05, tolerance: 2.219e+04
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.189e+05, tolerance: 2.254e+04
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.279e+05, tolerance: 2.399e+04
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.271e+01, tolerance: 2.254e+01
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.378e+01, tolerance: 2.211e+01
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.701e+01, tolerance: 2.399e+01
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.953e+05, tolerance: 2.219e+01
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.953e+05, tolerance: 2.219e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.953e+05, tolerance: 2.219e+03
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.953e+05, tolerance: 2.219e+04
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.122e+05, tolerance: 2.399e+01
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.879e+05, tolerance: 2.172e+01
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.879e+05, tolerance: 2.172e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.208e+05, tolerance: 2.211e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.038e+05, tolerance: 2.254e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.208e+05, tolerance: 2.211e+01
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.300e+05, tolerance: 2.219e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.038e+05, tolerance: 2.254e+03
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.122e+05, tolerance: 2.399e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.038e+05, tolerance: 2.254e+01
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.300e+05, tolerance: 2.219e+03
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.879e+05, tolerance: 2.172e+03
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.300e+05, tolerance: 2.219e+01
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.208e+05, tolerance: 2.211e+04
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.122e+05, tolerance: 2.399e+03
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.208e+05, tolerance: 2.211e+03
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.879e+05, tolerance: 2.172e+04
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.038e+05, tolerance: 2.254e+04
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.300e+05, tolerance: 2.219e+04
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.122e+05, tolerance: 2.399e+04
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.729e+01, tolerance: 2.172e+01
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.844e+04, tolerance: 2.399e+01
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.472e+05, tolerance: 2.219e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.326e+03, tolerance: 2.211e+01
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.880e+04, tolerance: 2.254e+03
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.844e+04, tolerance: 2.399e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.880e+04, tolerance: 2.254e+01
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.472e+05, tolerance: 2.219e+03
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.326e+03, tolerance: 2.211e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.472e+05, tolerance: 2.219e+01
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.880e+04, tolerance: 2.254e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.844e+04, tolerance: 2.399e+03
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.326e+03, tolerance: 2.211e+03
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.880e+04, tolerance: 2.254e+04
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.472e+05, tolerance: 2.219e+04
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.844e+04, tolerance: 2.399e+04
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.507e+05, tolerance: 2.172e+01
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.062e+05, tolerance: 2.211e+01
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.906e+05, tolerance: 2.254e+01
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.160e+05, tolerance: 2.219e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.160e+05, tolerance: 2.219e+01
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.985e+05, tolerance: 2.399e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.985e+05, tolerance: 2.399e+01
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.507e+05, tolerance: 2.172e+03
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.062e+05, tolerance: 2.211e+04
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.507e+05, tolerance: 2.172e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.062e+05, tolerance: 2.211e+03
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.062e+05, tolerance: 2.211e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.906e+05, tolerance: 2.254e+04
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.906e+05, tolerance: 2.254e+03
#   model = cd_fast.enet_coordinate_descent(
# ...
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.522e+02, tolerance: 2.254e+01
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.738e+02, tolerance: 2.219e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.980e+02, tolerance: 2.219e+01
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.273e+02, tolerance: 2.399e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.645e+02, tolerance: 2.399e+01
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.301e+02, tolerance: 2.172e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.116e+02, tolerance: 2.211e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.522e+02, tolerance: 2.254e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.645e+02, tolerance: 2.399e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.329e+02, tolerance: 2.172e+01
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.426e+02, tolerance: 2.172e+01
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.913e+02, tolerance: 2.211e+01
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.058e+02, tolerance: 2.211e+01
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.263e+02, tolerance: 2.254e+01
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.435e+02, tolerance: 2.254e+01
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.140e+01, tolerance: 2.219e+01
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.155e+02, tolerance: 2.219e+01
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.289e+02, tolerance: 2.399e+01
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.463e+02, tolerance: 2.399e+01
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.426e+02, tolerance: 2.172e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.058e+02, tolerance: 2.211e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.435e+02, tolerance: 2.254e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.463e+02, tolerance: 2.399e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.263e+02, tolerance: 2.254e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.072e+02, tolerance: 2.211e+01
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.431e+02, tolerance: 2.254e+01
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.451e+02, tolerance: 2.399e+01
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.646e+01, tolerance: 2.172e+01
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.854e+01, tolerance: 2.211e+01
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.642e+01, tolerance: 2.254e+01
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.431e+02, tolerance: 2.254e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.677e+01, tolerance: 2.399e+01
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.451e+02, tolerance: 2.399e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.424e+02, tolerance: 2.211e+01
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.071e+02, tolerance: 2.254e+01
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.107e+02, tolerance: 2.399e+01
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.424e+02, tolerance: 2.211e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.071e+02, tolerance: 2.254e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.107e+02, tolerance: 2.399e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.223e+01, tolerance: 2.211e+01
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.049e+01, tolerance: 2.254e+01
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.398e+02, tolerance: 2.399e+01
#   model = cd_fast.enet_coordinate_descent(
# Best Model: XGBoost
# Best Scaling Method: Standard Scaling
# Best Parameters: {'gamma': 0, 'learning_rate': 0.05, 'max_depth': 7, 'min_child_weight': 1, 'n_estimators': 500, 'subsample': 0.9}
# Best MAE: 6.61083315239578

# %%
import numpy as np
from sklearn.linear_model import Lasso, Ridge, ElasticNet
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import mean_absolute_error

Robust_scaler = RobustScaler()
minmax_scaler = MinMaxScaler()
standard_scaler = StandardScaler()

# 데이터 및 스케일러가 주어진 것으로 가정
# X_train, X_val, y_train, y_val = ...
# minmax_scaler = ...
# standard_scaler = ...

# 모델 및 파라미터 그리드 설정
models = {
    'Lasso': Lasso(),
    'Ridge': Ridge(),
    'ElasticNet': ElasticNet(),
    'XGBoost' : xgb.XGBRegressor(objective='reg:squarederror', random_state=42)
    # 'RandomForest' : RandomForestRegressor(random_state=42)
}

params = {
    'Lasso': {
        'alpha': [0.001, 0.01, 0.1, 1, 10, 100],
        'max_iter': [1000,5000,10000],
        'tol': [0.00001,0.0001, 0.001]
    },
    'Ridge': {
        'alpha': [0.001, 0.01, 0.1, 1, 10, 100],
        'max_iter': [1000,5000,10000],
        'tol': [0.00001,0.0001, 0.001]
    },
    'ElasticNet': {
        'alpha': [0.001, 0.01, 0.1, 1, 10, 100],
        'l1_ratio': [.1, .5, .7, .9, .95, .99, 1],
        'max_iter': [500,1000,5000,10000],
        'tol': [0.00001,0.0001, 0.001]
    },
    'XGBoost' : {
                 'max_depth' : np.arange(5,9,1) ,
                  "n_estimators": [100, 500],
                  'min_child_weight' : np.arange(1, 5, 1), 
                  'gamma' : [0,1,2,3],
                  "learning_rate": [0.05, 0.075, 0.1],
                  'subsample' :np.arange(0.8, 1.0, 0.1)
    }
    # 'RandomForest' : {
    #     'n_estimators' : [100,500,1000],
    #     'max_features' :  ['sqrt'],
    #     'max_depth' : [40],
    #     'min_samples_split' :  [2],
    #     'bootstrap' :  [False]
    # }
}

# 스케일링 방법
scaling_methods = {
    'Robust Scaling': (X_train_non_store_robust, X_val_non_store_robust),
    'MinMax Scaling': (X_train_non_store_minmax, X_val_non_store_minmax),
    'Standard Scaling': (X_train_non_store_std, X_val_non_store_std)
}

# 그리드 서치 및 MAE 계산
best_mae = float('inf')
best_model = None
best_params = None
best_scaling = None

for name, model in models.items():
    for method, (X_train_non_store_scaled, X_val_non_store_scaled) in scaling_methods.items():
        grid = GridSearchCV(model, params[name], cv=5, n_jobs=-1, scoring='neg_mean_absolute_error')
        grid.fit(X_train_non_store_scaled, y_train_non_store)
        y_pred_non_store = grid.predict(X_val_non_store_scaled)
        mae = mean_absolute_error(y_val_non_store, y_pred_non_store)

        if mae < best_mae:
            best_mae_non_store = mae
            best_model_non_store = name
            best_params_non_store  = grid.best_params_
            best_scaling_non_store  = method

print(f"Best Model: {best_model_non_store}")
print(f"Best Scaling Method: {best_scaling_non_store}")
print(f"Best Parameters: {best_params_non_store}")
print(f"Best MAE: {best_mae_non_store}")

best_mae_store, best_mae_non_store
# Out:
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.517e+06, tolerance: 2.654e+03
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.136e+07, tolerance: 2.624e+03
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.517e+06, tolerance: 2.654e+04
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.894e+05, tolerance: 2.828e+03
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.711e+05, tolerance: 2.780e+03
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.711e+05, tolerance: 2.780e+04
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.894e+05, tolerance: 2.828e+04
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.172e+04, tolerance: 2.710e+03
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.136e+07, tolerance: 2.624e+04
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.136e+07, tolerance: 2.624e+05
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.517e+06, tolerance: 2.654e+05
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.782e+04, tolerance: 2.828e+03
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.965e+04, tolerance: 2.780e+03
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.640e+04, tolerance: 2.654e+03
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.662e+04, tolerance: 2.624e+04
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.965e+04, tolerance: 2.780e+04
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.662e+04, tolerance: 2.624e+03
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.713e+05, tolerance: 2.780e+03
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.896e+05, tolerance: 2.828e+03
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.136e+07, tolerance: 2.624e+03
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.622e+05, tolerance: 2.654e+03
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.713e+05, tolerance: 2.780e+04
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.136e+07, tolerance: 2.624e+04
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.180e+04, tolerance: 2.710e+03
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.622e+05, tolerance: 2.654e+04
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.136e+07, tolerance: 2.624e+05
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.896e+05, tolerance: 2.828e+04
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.649e+04, tolerance: 2.654e+03
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.974e+04, tolerance: 2.780e+03
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.791e+04, tolerance: 2.828e+03
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.671e+04, tolerance: 2.624e+04
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.974e+04, tolerance: 2.780e+04
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.671e+04, tolerance: 2.624e+03
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.550e+06, tolerance: 2.624e+03
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.624e+05, tolerance: 2.710e+03
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.766e+05, tolerance: 2.780e+03
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.837e+05, tolerance: 2.654e+04
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.837e+05, tolerance: 2.654e+03
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.550e+06, tolerance: 2.624e+04
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.461e+05, tolerance: 2.828e+03
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.766e+05, tolerance: 2.780e+04
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.624e+05, tolerance: 2.710e+04
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.461e+05, tolerance: 2.828e+04
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.837e+05, tolerance: 2.654e+05
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.766e+05, tolerance: 2.780e+05
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.550e+06, tolerance: 2.624e+05
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.461e+05, tolerance: 2.828e+05
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.837e+05, tolerance: 2.654e+03
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.691e+05, tolerance: 2.780e+03
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.467e+06, tolerance: 2.828e+03
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.345e+04, tolerance: 2.710e+03
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.837e+05, tolerance: 2.654e+04
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.549e+06, tolerance: 2.624e+04
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.549e+06, tolerance: 2.624e+03
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.691e+05, tolerance: 2.780e+04
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.467e+06, tolerance: 2.828e+04
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.549e+06, tolerance: 2.624e+05
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.837e+05, tolerance: 2.654e+05
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.487e+05, tolerance: 2.780e+03
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.435e+05, tolerance: 2.654e+03
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.069e+05, tolerance: 2.624e+03
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.467e+06, tolerance: 2.828e+03
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.345e+04, tolerance: 2.710e+03
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.435e+05, tolerance: 2.654e+04
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.487e+05, tolerance: 2.780e+04
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.069e+05, tolerance: 2.624e+04
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.459e+05, tolerance: 2.654e+03
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.509e+05, tolerance: 2.780e+03
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.090e+05, tolerance: 2.624e+03
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.471e+06, tolerance: 2.828e+03
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.396e+04, tolerance: 2.710e+03
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.459e+05, tolerance: 2.654e+04
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.090e+05, tolerance: 2.624e+04
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.509e+05, tolerance: 2.780e+04
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.471e+06, tolerance: 2.828e+04
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.467e+06, tolerance: 2.828e+04
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.461e+04, tolerance: 2.654e+03
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.683e+04, tolerance: 2.780e+03
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.523e+04, tolerance: 2.624e+03
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.897e+03, tolerance: 2.624e+03
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.708e+03, tolerance: 2.654e+03
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.154e+04, tolerance: 2.780e+03
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.213e+03, tolerance: 2.828e+03
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.702e+05, tolerance: 2.710e+03
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.702e+05, tolerance: 2.710e+04
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.702e+05, tolerance: 2.710e+05
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.831e+04, tolerance: 2.654e+03
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.536e+06, tolerance: 2.710e+03
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.146e+04, tolerance: 2.828e+04
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.787e+04, tolerance: 2.780e+03
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.536e+06, tolerance: 2.710e+04
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.831e+04, tolerance: 2.654e+04
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.206e+04, tolerance: 2.624e+03
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.787e+04, tolerance: 2.780e+04
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.536e+06, tolerance: 2.710e+05
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.146e+04, tolerance: 2.828e+03
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.206e+04, tolerance: 2.624e+04
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.249e+07, tolerance: 2.654e+03
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.552e+07, tolerance: 2.710e+03
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.267e+07, tolerance: 2.780e+03
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.284e+07, tolerance: 2.828e+04
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.249e+07, tolerance: 2.654e+04
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.034e+07, tolerance: 2.624e+03
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.552e+07, tolerance: 2.710e+04
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.267e+07, tolerance: 2.780e+04
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.284e+07, tolerance: 2.828e+03
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.034e+07, tolerance: 2.624e+05
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.034e+07, tolerance: 2.624e+04
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.249e+07, tolerance: 2.654e+05
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.284e+07, tolerance: 2.828e+05
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.267e+07, tolerance: 2.780e+05
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.036e+05, tolerance: 2.710e+04
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.552e+07, tolerance: 2.710e+05
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.036e+05, tolerance: 2.710e+05
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.036e+05, tolerance: 2.710e+03
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.653e+07, tolerance: 2.654e+03
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.390e+07, tolerance: 2.710e+03
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.677e+07, tolerance: 2.828e+04
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.610e+07, tolerance: 2.780e+03
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.653e+07, tolerance: 2.654e+04
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.295e+07, tolerance: 2.624e+05
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.390e+07, tolerance: 2.710e+04
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.610e+07, tolerance: 2.780e+04
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.295e+07, tolerance: 2.624e+03
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.677e+07, tolerance: 2.828e+05
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.653e+07, tolerance: 2.654e+05
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.295e+07, tolerance: 2.624e+04
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.677e+07, tolerance: 2.828e+03
#   model = cd_fast.enet_coordinate_descent(
# ...
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.553e+06, tolerance: 2.624e+03
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.471e+06, tolerance: 2.828e+03
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.416e+04, tolerance: 2.710e+03
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.699e+05, tolerance: 2.780e+04
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.471e+06, tolerance: 2.828e+04
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.868e+05, tolerance: 2.654e+04
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.868e+05, tolerance: 2.654e+05
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.553e+06, tolerance: 2.624e+04
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.854e+03, tolerance: 2.654e+03
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.459e+05, tolerance: 2.654e+03
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.553e+06, tolerance: 2.624e+05
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.471e+06, tolerance: 2.828e+03
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.509e+05, tolerance: 2.780e+03
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.459e+05, tolerance: 2.654e+04
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.090e+05, tolerance: 2.624e+04
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.396e+04, tolerance: 2.710e+03
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.090e+05, tolerance: 2.624e+03
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.509e+05, tolerance: 2.780e+04
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.471e+06, tolerance: 2.828e+04
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.523e+04, tolerance: 2.624e+03
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.461e+04, tolerance: 2.654e+03
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.683e+04, tolerance: 2.780e+03
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.991e+03, tolerance: 2.654e+03
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.190e+03, tolerance: 2.624e+03
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.505e+04, tolerance: 2.654e+03
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.339e+03, tolerance: 2.654e+03
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.083e+04, tolerance: 2.654e+03
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.767e+04, tolerance: 2.780e+03
#   model = cd_fast.enet_coordinate_descent(
# /Users/seungwoo/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.995e+04, tolerance: 2.624e+03
#   model = cd_fast.enet_coordinate_descent(
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[245], line 74
#      72 for method, (X_train_non_store_scaled, X_val_non_store_scaled) in scaling_methods.items():
#      73     grid = GridSearchCV(model, params[name], cv=5, n_jobs=-1, scoring='neg_mean_absolute_error')
# ---> 74     grid.fit(X_train_non_store_scaled, y_train_non_store)
#      75     y_pred_non_store = grid.predict(X_val_non_store_scaled)
#      76     mae = mean_absolute_error(y_val_non_store, y_pred_non_store)
#
# File ~/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/base.py:1151, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1144     estimator._validate_params()
#    1146 with config_context(
#    1147     skip_parameter_validation=(
#    1148         prefer_skip_nested_validation or global_skip_validation
#    1149     )
#    1150 ):
# -> 1151     return fit_method(estimator, *args, **kwargs)
#
# File ~/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/model_selection/_search.py:898, in BaseSearchCV.fit(self, X, y, groups, **fit_params)
#     892     results = self._format_results(
#     893         all_candidate_params, n_splits, all_out, all_more_results
#     894     )
#     896     return results
# --> 898 self._run_search(evaluate_candidates)
#     900 # multimetric is determined here because in the case of a callable
#     901 # self.scoring the return type is only known after calling
#     902 first_test_score = all_out[0]["test_scores"]
#
# File ~/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/model_selection/_search.py:1419, in GridSearchCV._run_search(self, evaluate_candidates)
#    1417 def _run_search(self, evaluate_candidates):
#    1418     """Search all candidates in param_grid"""
# -> 1419     evaluate_candidates(ParameterGrid(self.param_grid))
#
# File ~/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/model_selection/_search.py:845, in BaseSearchCV.fit.<locals>.evaluate_candidates(candidate_params, cv, more_results)
#     837 if self.verbose > 0:
#     838     print(
#     839         "Fitting {0} folds for each of {1} candidates,"
#     840         " totalling {2} fits".format(
#     841             n_splits, n_candidates, n_candidates * n_splits
#     842         )
#     843     )
# --> 845 out = parallel(
#     846     delayed(_fit_and_score)(
#     847         clone(base_estimator),
#     848         X,
#     849         y,
#     850         train=train,
#     851         test=test,
#     852         parameters=parameters,
#     853         split_progress=(split_idx, n_splits),
#     854         candidate_progress=(cand_idx, n_candidates),
#     855         **fit_and_score_kwargs,
#     856     )
#     857     for (cand_idx, parameters), (split_idx, (train, test)) in product(
#     858         enumerate(candidate_params), enumerate(cv.split(X, y, groups))
#     859     )
#     860 )
#     862 if len(out) < 1:
#     863     raise ValueError(
#     864         "No fits were performed. "
#     865         "Was the CV iterator empty? "
#     866         "Were there no candidates?"
#     867     )
#
# File ~/miniconda3/envs/tf25/lib/python3.8/site-packages/sklearn/utils/parallel.py:65, in Parallel.__call__(self, iterable)
#      60 config = get_config()
#      61 iterable_with_config = (
#      62     (_with_config(delayed_func, config), args, kwargs)
#      63     for delayed_func, args, kwargs in iterable
#      64 )
# ---> 65 return super().__call__(iterable_with_config)
#
# File ~/miniconda3/envs/tf25/lib/python3.8/site-packages/joblib/parallel.py:1952, in Parallel.__call__(self, iterable)
#    1946 # The first item from the output is blank, but it makes the interpreter
#    1947 # progress until it enters the Try/Except block of the generator and
#    1948 # reach the first `yield` statement. This starts the aynchronous
#    1949 # dispatch of the tasks to the workers.
#    1950 next(output)
# -> 1952 return output if self.return_generator else list(output)
#
# File ~/miniconda3/envs/tf25/lib/python3.8/site-packages/joblib/parallel.py:1595, in Parallel._get_outputs(self, iterator, pre_dispatch)
#    1592     yield
#    1594     with self._backend.retrieval_context():
# -> 1595         yield from self._retrieve()
#    1597 except GeneratorExit:
#    1598     # The generator has been garbage collected before being fully
#    1599     # consumed. This aborts the remaining tasks if possible and warn
#    1600     # the user if necessary.
#    1601     self._exception = True
#
# File ~/miniconda3/envs/tf25/lib/python3.8/site-packages/joblib/parallel.py:1707, in Parallel._retrieve(self)
#    1702 # If the next job is not ready for retrieval yet, we just wait for
#    1703 # async callbacks to progress.
#    1704 if ((len(self._jobs) == 0) or
#    1705     (self._jobs[0].get_status(
#    1706         timeout=self.timeout) == TASK_PENDING)):
# -> 1707     time.sleep(0.01)
#    1708     continue
#    1710 # We need to be careful: the job list can be filling up as
#    1711 # we empty it and Python list are not thread-safe by
#    1712 # default hence the use of the lock
#
# KeyboardInterrupt:

# %%
X_test_store = test_store_data[features_store]
X_test_non_store = test_non_store_data[features_nonstore]

# %%
# 선택한 모델로 스케일링된 테스트 데이터에 대한 예측 수행 (상가)
X_test_store_scaled = None

# StandardScaler 인스턴스 생성
standard_scaler = StandardScaler()

# 학습 데이터에 대해 스케일러를 학습(fit)시킴


Robust_scaler = RobustScaler()
minmax_scaler = MinMaxScaler()
standard_scaler = StandardScaler()

if best_scaling_store == 'MinMax Scaling':
    minmax_scaler.fit(X_test_store)
    X_test_store_scaled = minmax_scaler.transform(X_test_store)
elif best_scaling_store == 'Standard Scaling':
    standard_scaler.fit(X_train_store)
    X_train_store_scaled = standard_scaler.transform(X_train_store)
    X_test_store_scaled = standard_scaler.transform(X_test_store)
elif best_scaling_store == 'Robust Scaling':
    Robust_scaler.fit(X_test_store)
    X_test_store_scaled = Robust_scaler.transform(X_test_store)

y_pred_test_store = None

if best_model_store == 'Lasso':
    model_store = Lasso(**best_params_store)
elif best_model_store == 'Ridge':
    model_store = Ridge(**best_params_store)
elif best_model_store == 'ElasticNet':
    model_store = ElasticNet(**best_params_store)
elif best_model_store == 'XGBoost':
    model_store = xgb.XGBRegressor(**best_params_store)
# elif best_model_store == 'RandomForest':
#     model_store = RandomForestRegressor(**best_params_store)        

model_store.fit(X_train_store_scaled, y_train_store)
y_pred_test_store = model_store.predict(X_test_store_scaled)

# %%
# 선택한 모델로 스케일링된 테스트 데이터에 대한 예측 수행 (상가가 아닌 것)
# 학습 데이터에 대해 스케일러를 학습(fit)시킴
X_test_non_store_scaled = None

Robust_scaler = RobustScaler()
minmax_scaler = MinMaxScaler()
standard_scaler = StandardScaler()

if best_scaling_non_store == 'MinMax Scaling':
    minmax_scaler.fit(X_test_non_store)
    standard_scaler.fit(X_train_store)
    X_test_non_store_scaled = minmax_scaler.transform(X_test_non_store)
elif best_scaling_non_store == 'Standard Scaling':
    standard_scaler.fit(X_train_non_store)
    X_train_non_store_scaled = standard_scaler.transform(X_train_non_store)
    X_test_non_store_scaled = standard_scaler.transform(X_test_non_store)
else :
    Robust_scaler.fit(X_test_non_store)
    X_test_store_scaled = Robust_scaler.transform(X_test_non_store)

y_pred_test_non_store = None

if best_model_non_store == 'Lasso':
    model_non_store = Lasso(**best_params_non_store)
elif best_model_non_store == 'Ridge':
    model_non_store = Ridge(**best_params_non_store)
elif best_model_non_store == 'ElasticNet':
    model_non_store = ElasticNet(**best_params_non_store)
elif best_model_store == 'XGBoost':
    model_non_store = xgb.XGBRegressor(**best_params_non_store)
# elif best_model_store == 'RandomForest':
#     model_non_store = RandomForestRegressor(**best_params_non_store)

model_non_store.fit(X_train_non_store_scaled, y_train_non_store)
y_pred_test_non_store = model_non_store.predict(X_test_non_store_scaled)

y_pred_test_store[y_pred_test_store < 0] = 0
y_pred_test_non_store[y_pred_test_non_store < 0] = 0

# # 로그 변환
# y_pred_test_store = np.log1p(y_pred_test_store)
# y_pred_test_non_store = np.log1p(y_pred_test_non_store)

# # 역 로그 변환
# y_pred_test_store = np.expm1(y_pred_test_store)
# y_pred_test_non_store = np.expm1(y_pred_test_non_store)

# 예측 결과를 원래 데이터 프레임에 추가
test_store_data['예측등록차량수'] = y_pred_test_store
test_non_store_data['예측등록차량수'] = y_pred_test_non_store

# 예측 결과 병합
test_encoded_combined = pd.concat([test_store_data, test_non_store_data])

# 각 단지코드의 예측된 등록차량수의 평균을 계산
submission = test_encoded_combined.groupby('단지코드')['예측등록차량수'].mean().reset_index()
submission.columns=['code','num']

# sample submission 양식에 맞게 결과 조정
final_submission = sample_submission.merge(submission, on='code', how='left')
final_submission = final_submission[['code', 'num_y']]
final_submission.columns = ['code', 'num']

final_submission.head()
# 예측 결과를 csv 파일로 저장
final_submission.to_csv('use_xgb_nature.csv', index=False)
